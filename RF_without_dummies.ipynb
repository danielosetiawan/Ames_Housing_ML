# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
rfdf = pd.read_csv('data/RF_LabEnc_data.csv')

# %%
target = rfdf['SalePrice']
df = rfdf.drop(['Unnamed: 0', 'PID', 'SalePrice'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 85 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GrLivArea        2580 non-null   int64
#  1   MSSubClass       2580 non-null   int64
#  2   MSZoning         2580 non-null   int64
#  3   LotFrontage      2580 non-null   float64
#  4   LotArea          2580 non-null   int64
#  5   Street           2580 non-null   int64
#  6   Alley            2580 non-null   int64
#  7   LotShape         2580 non-null   int64
#  8   LandContour      2580 non-null   int64
#  9   Utilities        2580 non-null   int64
#  10  LotConfig        2580 non-null   int64
#  11  LandSlope        2580 non-null   int64
#  12  Neighborhood     2580 non-null   int64
#  13  Condition1       2580 non-null   int64
#  14  Condition2       2580 non-null   int64
#  15  BldgType         2580 non-null   int64
#  16  HouseStyle       2580 non-null   int64
#  17  OverallQual      2580 non-null   int64
#  18  OverallCond      2580 non-null   int64
#  19  YearBuilt        2580 non-null   int64
#  20  YearRemodAdd     2580 non-null   int64
#  21  RoofStyle        2580 non-null   int64
#  22  RoofMatl         2580 non-null   int64
#  23  Exterior1st      2580 non-null   int64
#  24  Exterior2nd      2580 non-null   int64
#  25  MasVnrType       2580 non-null   int64
#  26  MasVnrArea       2580 non-null   float64
#  27  ExterQual        2580 non-null   int64
#  28  ExterCond        2580 non-null   int64
#  29  Foundation       2580 non-null   int64
#  30  BsmtQual         2580 non-null   int64
#  31  BsmtCond         2580 non-null   int64
#  32  BsmtExposure     2580 non-null   int64
#  33  BsmtFinType1     2580 non-null   int64
#  34  BsmtFinSF1       2580 non-null   float64
#  35  BsmtFinType2     2580 non-null   int64
#  36  BsmtFinSF2       2580 non-null   float64
#  37  BsmtUnfSF        2580 non-null   float64
#  38  TotalBsmtSF      2580 non-null   float64
#  39  Heating          2580 non-null   int64
#  40  HeatingQC        2580 non-null   int64
#  41  CentralAir       2580 non-null   int64
#  42  Electrical       2580 non-null   int64
#  43  1stFlrSF         2580 non-null   int64
#  44  2ndFlrSF         2580 non-null   int64
#  45  LowQualFinSF     2580 non-null   int64
#  46  BsmtFullBath     2580 non-null   float64
#  47  BsmtHalfBath     2580 non-null   float64
#  48  FullBath         2580 non-null   int64
#  49  HalfBath         2580 non-null   int64
#  50  BedroomAbvGr     2580 non-null   int64
#  51  KitchenAbvGr     2580 non-null   int64
#  52  KitchenQual      2580 non-null   int64
#  53  TotRmsAbvGrd     2580 non-null   int64
#  54  Functional       2580 non-null   int64
#  55  Fireplaces       2580 non-null   int64
#  56  FireplaceQu      2580 non-null   int64
#  57  GarageType       2580 non-null   int64
#  58  GarageYrBlt      2580 non-null   float64
#  59  GarageFinish     2580 non-null   int64
#  60  GarageCars       2580 non-null   float64
#  61  GarageArea       2580 non-null   float64
#  62  GarageQual       2580 non-null   int64
#  63  GarageCond       2580 non-null   int64
#  64  PavedDrive       2580 non-null   int64
#  65  WoodDeckSF       2580 non-null   int64
#  66  OpenPorchSF      2580 non-null   int64
#  67  EnclosedPorch    2580 non-null   int64
#  68  3SsnPorch        2580 non-null   int64
#  69  ScreenPorch      2580 non-null   int64
#  70  PoolArea         2580 non-null   int64
#  71  PoolQC           2580 non-null   int64
#  72  Fence            2580 non-null   int64
#  73  MiscFeature      2580 non-null   int64
#  74  MiscVal          2580 non-null   int64
#  75  MoSold           2580 non-null   int64
#  76  YrSold           2580 non-null   int64
#  77  SaleType         2580 non-null   int64
#  78  SaleCondition    2580 non-null   int64
#  79  crime_rate       2580 non-null   int64
#  80  school_quality   2580 non-null   int64
#  81  HouseAge         2580 non-null   int64
#  82  LastRemod        2580 non-null   int64
#  83  nb_appreciation  2580 non-null   int64
#  84  nb_income        2580 non-null   int64
# dtypes: float64(11), int64(74)
# memory usage: 1.7 MB

# %%
RF = RandomForestRegressor(n_jobs=-1)
X_train, X_test, y_train, y_test= train_test_split(df, target, test_size=0.3, random_state = 0)

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid = {'min_samples_split':[4, 5, 12, 18], 
#               'min_samples_leaf':[1, 2, 5, 8], 
#               'n_estimators':[100, 200, 400, 500], 
#               'max_depth':[2, 4, 6, 10],
#               'max_features': ['auto', 'log2']}

# %%
# CV_RF = GridSearchCV(estimator= RF, param_grid = param_grid, cv=5)

# %%
# %time CV_RF.fit(X_train, y_train)
# Out:
# CPU times: user 7min 20s, sys: 1min 3s, total: 8min 24s
# Wall time: 13min 14s
# GridSearchCV(cv=5, estimator=RandomForestRegressor(n_jobs=-1),
#              param_grid={'max_depth': [2, 4, 6, 10],
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': [1, 2, 5, 8],
#                          'min_samples_split': [4, 5, 12, 18],
#                          'n_estimators': [100, 200, 400, 500]})

# %%
# CV_RF.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 200}

# %%
# CV_RF.best_score_
# Out:
# 0.881706579236371

# %%
# print(f'The R-squared on test set is {CV_RF.best_estimator_.score(X_test,y_test)}')
# print(f'The R-squared on train set is {CV_RF.best_estimator_.score(X_train,y_train)}')
# Out:
# The R-squared on test set is 0.9052805205268903
# The R-squared on train set is 0.9765311408690329

# %%
#CV_RF.best_estimator_.feature_importances_
# Out:
# array([1.26285530e-01, 1.95542467e-03, 1.30004380e-03, 3.44943842e-03,
#        1.07434348e-02, 1.52757335e-07, 1.53879049e-04, 7.01950024e-04,
#        8.13029031e-04, 2.39294335e-07, 4.61693309e-04, 5.78786334e-04,
#        3.83771219e-03, 5.96684202e-04, 2.88644130e-04, 6.83967094e-04,
#        6.94433986e-04, 5.32766548e-01, 3.34700407e-03, 3.41901260e-03,
#        3.74594708e-03, 6.46853798e-04, 1.91675530e-04, 9.62208886e-04,
#        9.23513537e-04, 3.49844520e-04, 6.84835391e-03, 5.59321812e-03,
#        4.01924338e-04, 4.26959344e-04, 2.87895584e-03, 4.50647173e-04,
#        1.57547661e-03, 3.48134312e-03, 2.57578288e-02, 4.64631076e-04,
#        7.57149436e-04, 3.80413039e-03, 4.44400383e-02, 8.05542362e-05,
#        7.62184243e-04, 1.85415723e-03, 1.55167057e-04, 6.12133460e-02,
#        4.41844544e-03, 4.13737951e-05, 1.72419940e-03, 1.54603216e-04,
#        2.18044655e-02, 7.99354838e-04, 9.70703761e-04, 1.43635082e-04,
#        4.88253801e-03, 1.67871124e-03, 4.38273825e-04, 3.71940589e-03,
#        3.06968039e-03, 3.79617908e-03, 2.46467981e-02, 2.32529145e-03,
#        4.02755597e-05, 2.56441841e-02, 1.48748315e-04, 2.41686237e-04,
#        3.81927037e-04, 4.41986995e-03, 3.70975314e-03, 3.62819385e-04,
#        1.15465023e-04, 2.02213485e-03, 1.67782272e-05, 7.34060854e-06,
#        1.72703649e-04, 1.17453399e-05, 4.41101196e-05, 7.29668240e-03,
#        1.09364095e-03, 3.71320807e-04, 1.15063265e-03, 2.14113996e-03,
#        3.31792585e-03, 5.59138847e-03, 4.62008089e-03, 1.75720908e-03,
#        8.63062094e-04])

# %%
#CV_RF2 = GridSearchCV(estimator= RF, param_grid = param_grid, cv=10)
#%time CV_RF2.fit(X_train, y_train)
# Out:
# CPU times: user 14min 43s, sys: 2min 15s, total: 16min 58s
# Wall time: 28min 25s
# GridSearchCV(cv=10, estimator=RandomForestRegressor(n_jobs=-1),
#              param_grid={'max_depth': [2, 4, 6, 10],
#                          'max_features': ['auto', 'log2'],
#                          'min_samples_leaf': [1, 2, 5, 8],
#                          'min_samples_split': [4, 5, 12, 18],
#                          'n_estimators': [100, 200, 400, 500]})

# %%
#CV_RF2.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
#CV_RF2.best_score_
# Out:
# 0.8847395912939324

# %%
#print(f'The R-squared on test set is {CV_RF2.best_estimator_.score(X_test,y_test)}')
#print(f'The R-squared on train set is {CV_RF2.best_estimator_.score(X_train,y_train)}')
# Out:
# The R-squared on test set is 0.898996305565986
# The R-squared on train set is 0.9691473623550517

# %%
 RF2 = RandomForestRegressor(n_jobs=-1, max_depth = 10, min_samples_leaf = 2, n_estimators = 500, min_samples_split = 5)

# %%
RF2.fit(X_train, y_train)
print(f'The R-squared on test set is {RF2.score(X_test,y_test)}')
print(f'The R-squared on train set is {RF2.score(X_train,y_train)}')
# Out:
# The R-squared on test set is 0.9053395275405406
# The R-squared on train set is 0.9707279380400271

# %%
## Fixing the hyperparameters (grid search is very expensive), we'll do some feature reduction by looking at permuation importance.

from sklearn.inspection import permutation_importance


ls = []
feat_list = []
Xtest_list = [X_test]
Xtrain_list = [X_train]

# %%
pd.set_option('display.max_columns', 100)
X_test
# Out:
#       GrLivArea  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 953        1053          20         5         60.0     8250       1      1
# 330        1127          20         5         65.0     6500       1      1
# 670        1128          50         1         60.0     7500       1      1
# 302        1468          20         5         74.0     9612       1      1
# 436        1285          20         5         71.0     8197       1      1
# ...         ...         ...       ...          ...      ...     ...    ...
# 299        1656          80         6         75.0     6000       1      1
# 1193       1490          60         5         57.0     8918       1      1
# 1714       1150          20         5         70.0     7000       1      1
# 485        1709         120         2         50.0     5119       1      1
# 233        1976          60         5         84.0     9660       1      1
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 953          3            3          0          0          0            15
# 330          3            3          0          4          0             7
# 670          3            3          0          4          0            11
# 302          3            3          0          4          0            24
# 436          3            3          0          4          0            22
# ...        ...          ...        ...        ...        ...           ...
# 299          3            3          0          4          0            11
# 1193         0            3          0          4          0             8
# 1714         3            3          0          4          0            15
# 485          0            3          0          1          0            24
# 233          0            3          0          4          0            18
#
#       Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 953            2           2         0           2            5            7
# 330            2           2         0           2            6            6
# 670            2           2         0           0            4            4
# 302            1           2         0           2            8            5
# 436            2           2         0           2            6            5
# ...          ...         ...       ...         ...          ...          ...
# 299            2           2         0           7            5            5
# 1193           2           2         0           5            6            5
# 1714           2           2         0           2            5            4
# 485            2           2         4           2            9            5
# 233            2           2         0           5            8            5
#
#       YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 953        1963          1963          1         0            8            8
# 330        1976          1976          3         0            6            9
# 670        1920          1950          1         0            8            8
# 302        2008          2009          1         0           12           13
# 436        1977          1977          1         0            9            9
# ...         ...           ...        ...       ...          ...          ...
# 299        1967          1967          3         0            6            9
# 1193       2005          2006          1         0           12           13
# 1714       1961          1961          3         0            3            3
# 485        1999          2000          1         0            8            8
# 233        1998          1998          1         0           12           13
#
#       MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 953            2         0.0          3          4           1         3
# 330            1        84.0          3          4           1         3
# 670            2         0.0          3          2           1         3
# 302            3        72.0          2          4           2         4
# 436            1       148.0          3          4           1         3
# ...          ...         ...        ...        ...         ...       ...
# 299            2         0.0          1          4           1         4
# 1193           2         0.0          2          4           2         4
# 1714           2         0.0          3          4           1         3
# 485            1        60.0          2          4           2         5
# 233            1       242.0          2          4           2         4
#
#       BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 953          3             1             5       288.0             1
# 330          5             1             4      1033.0             1
# 670          3             1             1         0.0             1
# 302          3             1             1         0.0             1
# 436          3             1             1         0.0             1
# ...        ...           ...           ...         ...           ...
# 299          3             2             3       257.0             1
# 1193         3             4             1         0.0             1
# 1714         3             1             6       781.0             1
# 485          3             4             6      1238.0             1
# 233          3             1             6       791.0             1
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 953          0.0      765.0       1053.0        1          2           1
# 330          0.0       94.0       1127.0        1          4           1
# 670          0.0      698.0        698.0        1          4           1
# 302          0.0     1468.0       1468.0        1          0           1
# 436          0.0      660.0        660.0        1          0           1
# ...          ...        ...          ...      ...        ...         ...
# 299          0.0      367.0        624.0        1          0           1
# 1193         0.0      745.0        745.0        1          0           1
# 1714         0.0      369.0       1150.0        1          4           1
# 485          0.0      460.0       1698.0        1          0           1
# 233          0.0      253.0       1044.0        1          0           1
#
#       Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  BsmtFullBath  \
# 953            3      1053         0             0           1.0
# 330            3      1127         0             0           0.0
# 670            0       698       430             0           0.0
# 302            3      1468         0             0           0.0
# 436            3      1285         0             0           0.0
# ...          ...       ...       ...           ...           ...
# 299            3      1092       564             0           0.0
# 1193           3       745       745             0           0.0
# 1714           3      1150         0             0           0.0
# 485            3      1709         0             0           1.0
# 233            3      1079       897             0           1.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 953            0.0         1         0             3             1
# 330            1.0         1         1             3             1
# 670            0.0         1         0             2             1
# 302            0.0         2         0             3             1
# 436            0.0         1         1             3             1
# ...            ...       ...       ...           ...           ...
# 299            0.0         1         1             3             1
# 1193           0.0         2         1             3             1
# 1714           0.0         1         0             3             1
# 485            0.0         2         0             2             1
# 233            0.0         2         1             3             1
#
#       KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 953             2             6           6           0            0
# 330             4             6           6           1            1
# 670             4             6           6           0            0
# 302             2             6           6           1            4
# 436             4             7           6           1            3
# ...           ...           ...         ...         ...          ...
# 299             4             7           4           1            1
# 1193            2             7           6           1            4
# 1714            4             6           6           0            0
# 485             2             5           6           1            3
# 233             2             7           6           1            5
#
#       GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 953            0       1963.0             2         2.0       692.0
# 330            5       1976.0             1         2.0       480.0
# 670            5       1920.0             2         2.0       528.0
# 302            1       2008.0             3         2.0       898.0
# 436            1       1977.0             2         2.0       528.0
# ...          ...          ...           ...         ...         ...
# 299            1       1967.0             1         2.0       288.0
# 1193           1       2005.0             3         2.0       392.0
# 1714           1       1961.0             2         2.0       288.0
# 485            1       1999.0             3         2.0       506.0
# 233            1       1998.0             3         2.0       885.0
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  \
# 953            3           3           2         240            0
# 330            3           3           2           0            0
# 670            3           3           2          30            0
# 302            3           3           2         210          150
# 436            3           3           2         138            0
# ...          ...         ...         ...         ...          ...
# 299            3           3           2           0          180
# 1193           3           3           2          36           20
# 1714           3           3           2           0            0
# 485            3           3           2          97           65
# 233            3           3           2         210           31
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  \
# 953               0          0          109         0       0      0
# 330             138          0            0         0       0      0
# 670             164          0            0         0       0      0
# 302               0          0            0         0       0      0
# 436               0          0            0         0       0      3
# ...             ...        ...          ...       ...     ...    ...
# 299               0          0          100         0       0      3
# 1193              0          0            0         0       0      0
# 1714              0          0          162         0       0      0
# 485               0          0            0         0       0      0
# 233               0          0            0         0       0      0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 953             1        0       7    2007         9              4
# 330             1        0       5    2008         9              4
# 670             1        0       4    2010         0              0
# 302             1        0      12    2009         6              5
# 436             1        0       4    2007         9              4
# ...           ...      ...     ...     ...       ...            ...
# 299             1        0       7    2008         9              4
# 1193            1        0       7    2009         9              4
# 1714            1        0       7    2006         9              4
# 485             1        0       1    2008         1              0
# 233             1        0       2    2006         9              4
#
#       crime_rate  school_quality  HouseAge  LastRemod  nb_appreciation  \
# 953            1               5        44         44                4
# 330            1               4        32         32                6
# 670            0               6        90         60                3
# 302            6               7         1          0                9
# 436            5               2        30         30                5
# ...          ...             ...       ...        ...              ...
# 299            0               6        41         41                3
# 1193           5              10         4          3                6
# 1714           1               5        45         45                4
# 485            6               7         9          8                9
# 233            6               7         8          8                9
#
#       nb_income
# 953           2
# 330           7
# 670           6
# 302           5
# 436           5
# ...         ...
# 299           6
# 1193          5
# 1714          2
# 485           5
# 233           5
#
# [774 rows x 85 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

for j in range(0,85):
    results = permutation_importance(RF2.fit(Xtrain_list[j], y_train), 
                                     Xtest_list[j], 
                                     y_test, 
                                     scoring='neg_mean_squared_error')
    # get importance
    sorted_idx = results.importances_mean.argsort()

    feature_rank = {}
    features = np.array(Xtest_list[j].columns.values)
    feat_list.append(features)
    # summarize feature importance
    for i in sorted_idx[::-1]:
        data = {features[i]: results.importances_mean[i]}
        feature_rank.update(data)
    
    last_feat = list(feature_rank)[-1]
    del feature_rank[last_feat]
    ls.append(RandomForestRegressor(n_jobs=-1, 
                                    max_depth = 10, 
                                    min_samples_leaf = 2, 
                                    n_estimators = 500, 
                                    min_samples_split = 5)
              .fit(Xtrain_list[j], y_train))
    Xtest_list.append(X_test[list(feature_rank)])
    Xtrain_list.append(X_train[list(feature_rank)])

# %%
ls[2].feature_names_in_
# Out:
# array(['OverallQual', 'GrLivArea', '1stFlrSF', 'TotalBsmtSF',
#        'GarageArea', 'BsmtFinSF1', 'GarageYrBlt', 'LotArea', 'MasVnrArea',
#        'YearRemodAdd', 'BsmtFinType1', 'OverallCond', 'LastRemod',
#        'Neighborhood', '2ndFlrSF', 'Fireplaces', 'KitchenQual',
#        'school_quality', 'HouseAge', 'FireplaceQu', 'BsmtQual',
#        'ScreenPorch', 'crime_rate', 'nb_appreciation', 'FullBath',
#        'BsmtFullBath', 'MSZoning', 'CentralAir', 'YearBuilt',
#        'BsmtExposure', 'GarageType', 'LotFrontage', 'TotRmsAbvGrd',
#        'BsmtUnfSF', 'ExterQual', 'MSSubClass', 'GarageFinish',
#        'HeatingQC', 'WoodDeckSF', 'Exterior1st', 'nb_income', 'BldgType',
#        'OpenPorchSF', 'LandContour', 'LotShape', 'HalfBath', 'PavedDrive',
#        'BsmtCond', 'LandSlope', 'SaleType', 'BedroomAbvGr', 'Foundation',
#        'Functional', 'LotConfig', 'GarageCond', 'MasVnrType',
#        'Condition1', 'Exterior2nd', 'ExterCond', 'SaleCondition',
#        'KitchenAbvGr', 'RoofStyle', 'GarageQual', 'Alley', 'GarageCars',
#        'Condition2', 'Electrical', 'LowQualFinSF', 'MiscVal',
#        'MiscFeature', 'PoolArea', 'PoolQC', 'Utilities', 'Street',
#        '3SsnPorch', 'EnclosedPorch', 'BsmtHalfBath', 'Heating', 'Fence',
#        'HouseStyle', 'RoofMatl', 'BsmtFinType2', 'BsmtFinSF2'],
#       dtype=object)

# %%
len(ls)
# Out:
# 85

# %%
df1 = pd.DataFrame(columns=['R-sq', 'Num_of_feat'])
for i in range(0,85):
    df1=df1.append({'R-sq':ls[i].score(Xtest_list[i], y_test), 'Num_of_feat': 85-i}, ignore_index=True)

# %%
from matplotlib import pyplot as plt
fig = plt.figure()
plt.plot(df1['Num_of_feat'], df1['R-sq'])
plt.xlabel('Number of model features')
plt.ylabel('R-square value')
fig.savefig('rf_feat_imp.png', dpi=1600)

# %%
df1.to_csv('RF_Rsq_v_feat.csv')

# %%
Models = []
Models.append(ls)
Models.append(Xtest_list)
Models.append(Xtrain_list)

import pickle

# %%
filename = 'RF_models.sav'
pickle.dump(Models, open(filename, 'wb'))
